# %%
# %ls Data
# Out:
#  驱动器 F 中的卷是 娱乐
#  卷的序列号是 0001-61CC
#
#  F:\test\Data 的目录
#
# 2018/11/16  13:15    <DIR>          .
# 2018/11/16  13:15    <DIR>          ..
# 2018/11/15  20:58    <DIR>          .ipynb_checkpoints
# 2018/11/13  09:55           430,463 20181112DataFrame数据库的操作处理.ipynb
# 2018/11/14  16:01            15,259 20181114特朗普就职演讲词文本统计.ipynb
# 2018/11/15  20:58            55,823 20181115NaN_缺失值数据清洗.ipynb
# 2018/11/13  14:58           181,400 2018年个人用电情况.ipynb
# 2018/11/15  20:22            47,368 house.csv
# 2017/06/05  08:20            47,629 house_data.csv
# 2017/06/05  08:20            14,551 house_sample.xlsx
# 2018/10/06  20:22        46,817,200 NationalNames.csv
# 2017/11/13  19:09            44,028 Pokemon.csv
# 2017/11/13  19:09        10,578,201 usa_flights.csv
# 2018/11/06  20:06           136,279 个人用电情况报表.xlsx
#               11 个文件     58,368,201 字节
#                3 个目录 347,937,595,392 可用字节

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Data/house_sample.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 29
# Data columns (total 11 columns):
# 标题       29 non-null object
# 建筑面积     29 non-null float64
# 总价       29 non-null int64
# 户型       29 non-null object
# 朝向       29 non-null object
# 物 业 费    29 non-null object
# 环比上月     29 non-null object
# 张贴日期     29 non-null object
# 产权性质     29 non-null object
# 装修       29 non-null object
# 楼层       29 non-null object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 1.7+ KB

# %%
df.dtypes
# Out:
# 标题        object
# 建筑面积     float64
# 总价         int64
# 户型        object
# 朝向        object
# 物 业 费     object
# 环比上月      object
# 张贴日期      object
# 产权性质      object
# 装修        object
# 楼层        object
# dtype: object

# %%
df.head()
# Out:
#                                标题    建筑面积   总价        户型  朝向      物 业 费  \
# 0    资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  南北  1.5元/平米・月
# 1     未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  南北    1.8元/・月
# 2      双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  南北       暂无资料
# 3      坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  南北       暂无资料
# 4  对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫   南  0.8元/平米・月
#
#      环比上月          张贴日期  产权性质    装修  楼层
# 0  ↑1.44%  西元2017年4月12日   商品房  豪华装修  低层
# 1  ↑4.08%  西元2017年4月13日   商品房   精装修  中层
# 2  ↓0.01%  西元2017年4月14日   商品房   精装修  高层
# 3  ↓0.01%  西元2017年4月15日   商品房   简装修  中层
# 4  ↓2.62%  西元2017年4月16日  个人产权   中装修  低层

# %% [markdown]
# * 虚拟变量

# %%
pd.get_dummies(df['朝向'])# 创建虚拟变量
df = pd.concat([df,pd.get_dummies(df['朝向'])],axis=1)
df.head()
# Out:
#                                标题    建筑面积   总价        户型  朝向      物 业 费  \
# 0    资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  南北  1.5元/平米・月
# 1     未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  南北    1.8元/・月
# 2      双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  南北       暂无资料
# 3      坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  南北       暂无资料
# 4  对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫   南  0.8元/平米・月
#
#      环比上月          张贴日期  产权性质    装修  楼层  南  南北
# 0  ↑1.44%  西元2017年4月12日   商品房  豪华装修  低层  0   1
# 1  ↑4.08%  西元2017年4月13日   商品房   精装修  中层  0   1
# 2  ↓0.01%  西元2017年4月14日   商品房   精装修  高层  0   1
# 3  ↓0.01%  西元2017年4月15日   商品房   简装修  中层  0   1
# 4  ↓2.62%  西元2017年4月16日  个人产权   中装修  低层  1   0

# %%
df.drop('朝向',axis=1,inplace=True)

# %%
df.head()
# Out:
#                                标题    建筑面积   总价        户型      物 业 费    环比上月  \
# 0    资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  1.5元/平米・月  ↑1.44%
# 1     未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫    1.8元/・月  ↑4.08%
# 2      双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫       暂无资料  ↓0.01%
# 3      坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫       暂无资料  ↓0.01%
# 4  对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫  0.8元/平米・月  ↓2.62%
#
#            张贴日期  产权性质    装修  楼层  南  南北
# 0  西元2017年4月12日   商品房  豪华装修  低层  0   1
# 1  西元2017年4月13日   商品房   精装修  中层  0   1
# 2  西元2017年4月14日   商品房   精装修  高层  0   1
# 3  西元2017年4月15日   商品房   简装修  中层  0   1
# 4  西元2017年4月16日  个人产权   中装修  低层  1   0

# %%
df[['室','厅','厨','卫']] = df['户型'].str.extract('(\d+)室(\d+)厅(\d+)厨(\d+)卫',expand=False)

# %%
df.head()
# Out:
#                                标题    建筑面积   总价        户型      物 业 费    环比上月  \
# 0    资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  1.5元/平米・月  ↑1.44%
# 1     未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫    1.8元/・月  ↑4.08%
# 2      双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫       暂无资料  ↓0.01%
# 3      坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫       暂无资料  ↓0.01%
# 4  对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫  0.8元/平米・月  ↓2.62%
#
#            张贴日期  产权性质    装修  楼层  南  南北  室  厅  厨  卫
# 0  西元2017年4月12日   商品房  豪华装修  低层  0   1  3  2  0  2
# 1  西元2017年4月13日   商品房   精装修  中层  0   1  2  2  1  1
# 2  西元2017年4月14日   商品房   精装修  高层  0   1  3  2  1  2
# 3  西元2017年4月15日   商品房   简装修  中层  0   1  2  1  1  1
# 4  西元2017年4月16日  个人产权   中装修  低层  1   0  2  1  1  1
