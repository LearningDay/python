# %% [markdown]
# [matplotlib.org](https://matplotlib.org/)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s = pd.Series(np.random.randn(1000))

# %% [markdown]
# ## 直方图
# * hist

# %%
plt.hist(s)
# Out:
# (array([  6.,  27.,  81., 166., 228., 220., 166.,  75.,  27.,   4.]),
#  array([-3.01503590e+00, -2.41151322e+00, -1.80799054e+00, -1.20446786e+00,
#         -6.00945174e-01,  2.57750650e-03,  6.06100187e-01,  1.20962287e+00,
#          1.81314555e+00,  2.41666823e+00,  3.02019091e+00]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(s,rwidth=0.9)# rwidth,柱子宽度
# Out:
# (array([  6.,  27.,  81., 166., 228., 220., 166.,  75.,  27.,   4.]),
#  array([-3.01503590e+00, -2.41151322e+00, -1.80799054e+00, -1.20446786e+00,
#         -6.00945174e-01,  2.57750650e-03,  6.06100187e-01,  1.20962287e+00,
#          1.81314555e+00,  2.41666823e+00,  3.02019091e+00]),
#  <a list of 10 Patch objects>)

# %%
re = plt.hist(s)

# %%
re
# Out:
# (array([  6.,  27.,  81., 166., 228., 220., 166.,  75.,  27.,   4.]),
#  array([-3.01503590e+00, -2.41151322e+00, -1.80799054e+00, -1.20446786e+00,
#         -6.00945174e-01,  2.57750650e-03,  6.06100187e-01,  1.20962287e+00,
#          1.81314555e+00,  2.41666823e+00,  3.02019091e+00]),
#  <a list of 10 Patch objects>)

# %%
re[0]# 频率
# Out:
# array([  6.,  27.,  81., 166., 228., 220., 166.,  75.,  27.,   4.])

# %%
re[1]# bins
# Out:
# array([-3.01503590e+00, -2.41151322e+00, -1.80799054e+00, -1.20446786e+00,
#        -6.00945174e-01,  2.57750650e-03,  6.06100187e-01,  1.20962287e+00,
#         1.81314555e+00,  2.41666823e+00,  3.02019091e+00])

# %%
re[2]
# Out:
# <a list of 10 Patch objects>

# %%
plt.hist(s,rwidth=0.9,bins=20,color='r')
# Out:
# (array([  3.,   3.,   7.,  20.,  30.,  51.,  74.,  92., 107., 121., 126.,
#          94., 108.,  58.,  46.,  29.,  20.,   7.,   3.,   1.]),
#  array([-3.01503590e+00, -2.71327456e+00, -2.41151322e+00, -2.10975188e+00,
#         -1.80799054e+00, -1.50622920e+00, -1.20446786e+00, -9.02706515e-01,
#         -6.00945174e-01, -2.99183834e-01,  2.57750650e-03,  3.04338847e-01,
#          6.06100187e-01,  9.07861528e-01,  1.20962287e+00,  1.51138421e+00,
#          1.81314555e+00,  2.11490689e+00,  2.41666823e+00,  2.71842957e+00,
#          3.02019091e+00]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# # 密度图
# * kde

# %%
s.plot(kind='kde')
